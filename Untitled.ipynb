# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Listing status

# %%
import requests

url = "https://airbnb-listings.p.rapidapi.com/v2/listingstatus"

querystring = {"id":"619966061834034729","year":"2024","month":"1"}

headers = {
	"X-RapidAPI-Key": "b2b95a6827msha1cb6f6f392e51cp1893f6jsnd6b152f989ba",
	"X-RapidAPI-Host": "airbnb-listings.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

df = pd.DataFrame(response.json()['results'])
df
# Out:
#           date  calculated_status
# 0   2024-01-01                  0
# 1   2024-01-02                  0
# 2   2024-01-03                  0
# 3   2024-01-04                  0
# 4   2024-01-05                  0
# 5   2024-01-06                  0
# 6   2024-01-07                  0
# 7   2024-01-08                  0
# 8   2024-01-09                  0
# 9   2024-01-10                  0
# 10  2024-01-11                  0
# 11  2024-01-12                  0
# 12  2024-01-13                  0
# 13  2024-01-14                  0
# 14  2024-01-15                  0
# 15  2024-01-16                  0
# 16  2024-01-17                  0
# 17  2024-01-18                  0
# 18  2024-01-19                  0
# 19  2024-01-20                  0
# 20  2024-01-21                  0
# 21  2024-01-22                  0
# 22  2024-01-23                  0
# 23  2024-01-24                  0
# 24  2024-01-25                  0
# 25  2024-01-26                  0
# ...

# %% [markdown]
# ## Listing Reviews

# %% [markdown]
# Only output 20 first reviews since the `date_time`

# %%
import requests
import pandas as pd

url = "https://airbnb-listings.p.rapidapi.com/v2/listingReviews"

querystring = {"id":"728713662146364121","date_time":"2023-01-11 10:52:50","offset":"0"}

headers = {
	"X-RapidAPI-Key": "b2b95a6827msha1cb6f6f392e51cp1893f6jsnd6b152f989ba",
	"X-RapidAPI-Host": "airbnb-listings.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

df = pd.DataFrame(response.json()['results'])
df
# Out:
#               review_id                                           comments  \
# 0    944603960758954112  '편하게 쉬었어요! 깨끗하고, 에어컨이나 선풍기, TV 등 전자기기도 빵빵하고, 욕...
# 1    946770099172418176                                         'Miễn chê'
# 2    952596132989939072  'Très bon rapport qualité prix  Appartement sp...
# 3    954757523727512704  'Perfect location, just 15 minute walk to the ...
# 4    959075314716849664  'Absolute best place we stayed in Vietnam. Cle...
# 5    961980505506617984  'Nam’s place was great for our stay. The studi...
# 6    964151780201530368      '친절하고 정확한 안내, 좋은 접근성과 편의시설 등 전반적으로 맘에 들었습니다.'
# 7    967078553761056000              'Rất ưng ý, chủ nhà hỗ trợ rất tốt ạ'
# 8    969932159632492416  'Very nice, definitely recommend and would com...
# 9    972202674302497920  'Tôi rất khó tìm và mở phòng, đường vào nhà tố...
# 10   975761285906697344                         'Good, fast and efficient'
# ...

# %%
import requests
import pandas as pd

url = "https://airbnb-listings.p.rapidapi.com/v2/listingReviews"

querystring = {"id":"728713662146364121","date_time":"2023-01-11 10:52:50","offset":"15"}

headers = {
	"X-RapidAPI-Key": "b2b95a6827msha1cb6f6f392e51cp1893f6jsnd6b152f989ba",
	"X-RapidAPI-Host": "airbnb-listings.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

df = pd.DataFrame(response.json()['results'])
df
# Out:
#               review_id                                           comments  \
# 0    944603960758954112  '편하게 쉬었어요! 깨끗하고, 에어컨이나 선풍기, TV 등 전자기기도 빵빵하고, 욕...
# 1    946770099172418176                                         'Miễn chê'
# 2    952596132989939072  'Très bon rapport qualité prix  Appartement sp...
# 3    954757523727512704  'Perfect location, just 15 minute walk to the ...
# 4    959075314716849664  'Absolute best place we stayed in Vietnam. Cle...
# 5    961980505506617984  'Nam’s place was great for our stay. The studi...
# 6    964151780201530368      '친절하고 정확한 안내, 좋은 접근성과 편의시설 등 전반적으로 맘에 들었습니다.'
# 7    967078553761056000              'Rất ưng ý, chủ nhà hỗ trợ rất tốt ạ'
# 8    969932159632492416  'Very nice, definitely recommend and would com...
# 9    972202674302497920  'Tôi rất khó tìm và mở phòng, đường vào nhà tố...
# 10   975761285906697344                         'Good, fast and efficient'
# ...

# %% [markdown]
# ## Listing Infomations

# %%
import requests

url = "https://airbnb-listings.p.rapidapi.com/v2/listing"


querystring = {"id":"728713662146364121"}

headers = {
	"X-RapidAPI-Key": "b2b95a6827msha1cb6f6f392e51cp1893f6jsnd6b152f989ba",
	"X-RapidAPI-Host": "airbnb-listings.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

df = pd.DataFrame(response.json()['results'])
df.T
# Out:
#                                                                        0
# airbnb_id                                             728713662146364121
# city                                                          Tràng Tiền
# listingTitle           Trang Tien, Ha Noi center, old quarter, studio...
# isSuperhost                                                            1
# reviewCount                                                           92
# starRating                                                          4.87
# maxGuestCapacity                                                       2
# bedrooms                                                               1
# beds                                                                   1
# bathrooms                                                              1
# bathroomShared                                                         0
# propertyType                                          Serviced apartment
# ...

# %% [markdown]
# `user_id` stand for the owner_id
# ![image.png](attachment:image.png)

# %% [markdown]
# `listingLat` and `listingLng` is latitude and longtitude of the air bnb
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Listing all in state is `VN`

# %% [markdown]
# `offset = 0`: start at 0 index

# %%
import requests

url = "https://airbnb-listings.p.rapidapi.com/v2/listingsByGeoRef"

querystring = {"state":"VN","offset":"0"}

headers = {
	"X-RapidAPI-Key": "b2b95a6827msha1cb6f6f392e51cp1893f6jsnd6b152f989ba",
	"X-RapidAPI-Host": "airbnb-listings.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

# print(response.json()['results'])

df = pd.DataFrame(response.json()['results'])
df
# Out:
#              airbnb_id         last_updated     last_avail_check  \
# 0   728713662146364121  2024-03-25 21:00:27  2024-03-26 13:39:28
# 1   704177550111928546  2024-03-26 18:42:13  2024-03-27 22:19:08
# 2   672252024454608028  2024-03-26 15:02:25  2024-03-26 07:26:56
# 3   729315813116836137  2024-03-26 03:44:30  2024-03-26 10:30:06
# 4   728691856773604746  2024-03-27 11:50:58  2024-03-26 04:14:29
# 5             31528741  2024-03-26 00:27:29  2024-03-25 03:20:10
# 6   690966561732165321  2024-03-26 20:12:27  2024-03-25 10:38:06
# 7   735774180025113084  2024-03-26 14:59:00  2024-03-28 05:46:47
# 8   715043512896513043  2023-12-09 03:26:41  2023-12-16 02:31:34
# 9   710432629057230912  2024-03-24 01:19:42  2024-03-27 23:38:01
# 10  736739731585922628  2024-03-27 15:15:50  2024-03-26 07:25:26
# 11  733939557617812188  2024-03-26 05:00:42  2024-03-25 12:03:54
# 12  737306689583588784  2024-03-27 06:14:06  2024-03-25 08:53:39
# ...

# %%
import requests

url = "https://airbnb-listings.p.rapidapi.com/v2/listingsByGeoRef"

querystring = {"state":"VN","offset":"25"}

headers = {
	"X-RapidAPI-Key": "b2b95a6827msha1cb6f6f392e51cp1893f6jsnd6b152f989ba",
	"X-RapidAPI-Host": "airbnb-listings.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

# print(response.json()['results'])

df = pd.DataFrame(response.json()['results'])
df
# Out:
#              airbnb_id         last_updated     last_avail_check  \
# 0   736745626364846494  2024-03-27 22:26:40  2024-03-27 07:00:22
# 1             32679731  2024-03-27 20:28:16  2024-03-27 20:28:39
# 2   744594831716635845  2024-03-28 05:05:48  2024-03-25 10:39:54
# 3   747624559679701009  2024-03-23 15:55:29  2024-03-27 01:45:13
# 4   746893472498907556  2024-03-26 13:37:58  2024-03-25 09:21:08
# 5             43686365  2024-03-23 02:48:19  2024-03-25 19:08:45
# 6   744753302019539437  2023-10-08 13:45:10  2023-10-11 15:53:05
# 7             31570915  2023-11-14 12:47:47  2023-11-12 21:48:34
# 8   744558678591824861  2024-03-26 06:18:57  2024-03-27 05:12:19
# 9   744595478512900540  2024-03-26 00:03:26  2024-03-25 06:04:47
# 10            31544457  2024-03-26 22:26:05  2024-03-26 10:39:43
# 11  747607919842516715  2024-03-26 20:40:34  2024-03-26 19:25:22
# 12  743737095871923676  2023-12-09 21:32:46  2023-12-15 11:44:18
# ...

# %%
import requests

url = "https://airbnb-listings.p.rapidapi.com/v2/listingsByGeoRef"

querystring = {"state":"VN","offset":"50"}

headers = {
	"X-RapidAPI-Key": "b2b95a6827msha1cb6f6f392e51cp1893f6jsnd6b152f989ba",
	"X-RapidAPI-Host": "airbnb-listings.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

# print(response.json()['results'])

df = pd.DataFrame(response.json()['results'])
df
# Out:
#              airbnb_id         last_updated     last_avail_check  \
# 0             54375504  2024-03-26 07:48:06  2024-03-25 07:32:15
# 1   739345845978446748  2023-11-11 21:10:21  2023-11-13 12:24:57
# 2             24085695  2024-03-27 03:42:03  2024-03-25 13:42:10
# 3             53764468  2024-03-25 02:14:23  2024-03-25 13:38:51
# 4             48652822  2024-03-26 22:48:52  2024-03-27 20:47:37
# 5             43275009  2024-03-22 22:25:55  2024-03-27 23:53:45
# 6             41134800  2024-03-27 11:06:11  2024-03-25 21:34:37
# 7   664743814920298547  2024-03-26 15:02:19  2024-03-27 02:06:21
# 8   740354118698859502  2023-08-17 13:43:54  2023-07-24 15:56:07
# 9   659985346944116535  2024-03-27 06:35:13  2024-03-26 03:18:58
# 10  739741858908676014  2024-03-27 17:55:18  2024-03-27 21:40:01
# 11            39602214  2023-07-24 17:27:49  2023-07-24 15:45:04
# 12  741222173856862289  2024-03-25 09:21:54  2024-03-27 16:14:33
# ...

# %% [markdown]
# ## Hotel all infos

# %%
# https://www.airbnb.com.vn/rooms/{id}

# %% [markdown]
# ![image.png](attachment:image.png)
